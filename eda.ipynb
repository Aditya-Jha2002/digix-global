# %%
import pandas as pd

# %%
df_ads = pd.read_csv("data/train/train_data_ads.csv")
df_feed = pd.read_csv("data/train/train_data_feeds.csv")

# %%
test_ads = pd.read_csv("data/test/test_data_ads.csv")
test_feed = pd.read_csv("data/test/test_data_feeds.csv")

# %%
df_ads.head()
# Out:
#    log_id  label  user_id  age  gender  residence  city  city_rank  \
# 0  373250      0   100005    3       2         16   147          2
# 1  373253      1   100005    3       2         16   147          2
# 2  373252      1   100005    3       2         16   147          2
# 3  373251      0   100005    3       2         16   147          2
# 4  373255      0   100005    3       2         16   147          2
#
#    series_dev  series_group  ...       ad_click_list_v001  ad_click_list_v002  \
# 0          32             6  ...  30157^30648^14278^31706      2066^1776^1036
# 1          32             6  ...  30157^30648^14278^31706      2066^1776^1036
# 2          32             6  ...  30157^30648^14278^31706      2066^1776^1036
# 3          32             6  ...  30157^30648^14278^31706      2066^1776^1036
# 4          32             6  ...  30157^30648^14278^31706      2066^1776^1036
#
#    ad_click_list_v003  ad_close_list_v001  ad_close_list_v002  \
# ...

# %% [markdown]
# # Feed_data

# %%
print(f"Number of rows for the feed data: {len(df_feed)}")
print(f"Number of features for the feed data: {len(df_feed.columns)}")
# Out:
# Number of rows for the feed data: 3227732
# Number of features for the feed data: 28

# %%
df_feed.columns
# Out:
# Index(['u_userId', 'u_phonePrice', 'u_browserLifeCycle', 'u_browserMode',
#        'u_feedLifeCycle', 'u_refreshTimes', 'u_newsCatInterests',
#        'u_newsCatDislike', 'u_newsCatInterestsST', 'u_click_ca2_news',
#        'i_docId', 'i_s_sourceId', 'i_regionEntity', 'i_cat', 'i_entities',
#        'i_dislikeTimes', 'i_upTimes', 'i_dtype', 'e_ch', 'e_m', 'e_po', 'e_pl',
#        'e_rn', 'e_section', 'e_et', 'label', 'cillabel', 'pro'],
#       dtype='object')

# %%
test_feed.columns
# Out:
# Index(['u_userId', 'u_phonePrice', 'u_browserLifeCycle', 'u_browserMode',
#        'u_feedLifeCycle', 'u_refreshTimes', 'u_newsCatInterests',
#        'u_newsCatDislike', 'u_newsCatInterestsST', 'u_click_ca2_news',
#        'i_docId', 'i_s_sourceId', 'i_regionEntity', 'i_cat', 'i_entities',
#        'i_dislikeTimes', 'i_upTimes', 'i_dtype', 'e_ch', 'e_m', 'e_po', 'e_pl',
#        'e_rn', 'e_section', 'e_et', 'label', 'cillabel', 'pro'],
#       dtype='object')

# %%
df_feed.head()
# Out:
#    u_userId  u_phonePrice  u_browserLifeCycle  u_browserMode  u_feedLifeCycle  \
# 0    135880            16                  17             10               17
# 1    135880            16                  17             10               17
# 2    135880            16                  17             10               17
# 3    135880            16                  17             10               17
# 4    135880            16                  17             10               17
#
#    u_refreshTimes  u_newsCatInterests u_newsCatDislike u_newsCatInterestsST  \
# 0               0  195^168^109^98^108                0    195^44^168^112^21
# 1               0  195^168^109^98^108                0    195^44^168^112^21
# 2               0  195^168^109^98^108                0    195^44^168^112^21
# 3               0  195^168^109^98^108                0    195^44^168^112^21
# 4               0  195^168^109^98^108                0    195^44^168^112^21
#
# ...

# %% [markdown]
# # Ads_data

# %%
print(f"Number of rows for the feed data: {len(df_ads)}")
print(f"Number of features for the feed data: {len(df_ads.columns)}")
# Out:
# Number of rows for the feed data: 7675517
# Number of features for the feed data: 35

# %%
df_ads.columns
# Out:
# Index(['log_id', 'label', 'user_id', 'age', 'gender', 'residence', 'city',
#        'city_rank', 'series_dev', 'series_group', 'emui_dev', 'device_name',
#        'device_size', 'net_type', 'task_id', 'adv_id', 'creat_type_cd',
#        'adv_prim_id', 'inter_type_cd', 'slot_id', 'site_id', 'spread_app_id',
#        'hispace_app_tags', 'app_second_class', 'app_score',
#        'ad_click_list_v001', 'ad_click_list_v002', 'ad_click_list_v003',
#        'ad_close_list_v001', 'ad_close_list_v002', 'ad_close_list_v003',
#        'pt_d', 'u_newsCatInterestsST', 'u_refreshTimes', 'u_feedLifeCycle'],
#       dtype='object')

# %%
test_ads.columns
# Out:
# Index(['log_id', 'user_id', 'age', 'gender', 'residence', 'city', 'city_rank',
#        'series_dev', 'series_group', 'emui_dev', 'device_name', 'device_size',
#        'net_type', 'task_id', 'adv_id', 'creat_type_cd', 'adv_prim_id',
#        'inter_type_cd', 'slot_id', 'site_id', 'spread_app_id',
#        'hispace_app_tags', 'app_second_class', 'app_score',
#        'ad_click_list_v001', 'ad_click_list_v002', 'ad_click_list_v003',
#        'ad_close_list_v001', 'ad_close_list_v002', 'ad_close_list_v003',
#        'pt_d', 'u_newsCatInterestsST', 'u_refreshTimes', 'u_feedLifeCycle'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)
df_ads
# Out:
#          log_id  label  user_id  age  gender  residence  city  city_rank  \
# 0        373250      0   100005    3       2         16   147          2
# 1        373253      1   100005    3       2         16   147          2
# 2        373252      1   100005    3       2         16   147          2
# 3        373251      0   100005    3       2         16   147          2
# 4        373255      0   100005    3       2         16   147          2
# ...         ...    ...      ...  ...     ...        ...   ...        ...
# 7675512  650508      0   287180    6       4         33   319          3
# 7675513  650492      0   287180    6       4         33   319          3
# 7675514  650509      0   287180    6       4         33   319          3
# 7675515  650491      1   287180    6       4         33   319          3
# 7675516  650499      0   287180    6       4         33   319          3
#
#          series_dev  series_group  emui_dev  device_name  device_size  \
# ...

# %%
df_feed
# Out:
#          u_userId  u_phonePrice  u_browserLifeCycle  u_browserMode  \
# 0          135880            16                  17             10
# 1          135880            16                  17             10
# 2          135880            16                  17             10
# 3          135880            16                  17             10
# 4          135880            16                  17             10
# ...           ...           ...                 ...            ...
# 3227727    265431            14                  17             15
# 3227728    265431            14                  17             15
# 3227729    286542            16                  11             10
# 3227730    286542            16                  11             10
# 3227731    286542            16                  11             10
#
#          u_feedLifeCycle  u_refreshTimes  u_newsCatInterests u_newsCatDislike  \
# 0                     17               0  195^168^109^98^108                0
# ...

# %%
test_ads = pd.read_csv("data/test/test_data_ads.csv")
test_feed = pd.read_csv("data/test/test_data_feeds.csv")

# %%
train = pd.read_csv("data/test/test_data_ads.csv")
train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/adityajha/Documents/Dev/cross-domain-ctr/DCN/eda.ipynb Cell 17 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/adityajha/Documents/Dev/cross-domain-ctr/DCN/eda.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> train = pd.read_csv("data/test/test_data_ads.csv")
#       <a href='vscode-notebook-cell:/Users/adityajha/Documents/Dev/cross-domain-ctr/DCN/eda.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> train
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
test = pd.read_csv("data/test/test_data_file.csv")
test
# Out:
# /var/folders/4g/1h_0gphd53sg51js_h0qbbfh0000gn/T/ipykernel_17913/274059585.py:2: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   test = pd.read_csv("data/test/test_data_file.csv")
#         log_id  user_id  age  gender  residence  city  city_rank  series_dev  \
# 0       242295   100002    2       3         13   225          2          31
# 1       242300   100002    2       3         13   225          2          31
# 2       242299   100002    2       3         13   225          2          31
# 3       242296   100002    2       3         13   225          2          31
# 4       242293   100002    2       3         13   225          2          31
# ...        ...      ...  ...     ...        ...   ...        ...         ...
# 976053  653084   287180    6       4         33   319          3          27
# 976054  653074   287180    6       4         33   319          3          27
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
test
# Out:
#         log_id  user_id  age  gender  residence  city  city_rank  series_dev  \
# 0       242295   100002    2       3         13   225          2          31
# 1       242300   100002    2       3         13   225          2          31
# 2       242299   100002    2       3         13   225          2          31
# 3       242296   100002    2       3         13   225          2          31
# 4       242293   100002    2       3         13   225          2          31
# ...        ...      ...  ...     ...        ...   ...        ...         ...
# 976053  653084   287180    6       4         33   319          3          27
# 976054  653074   287180    6       4         33   319          3          27
# 976055  653076   287180    6       4         33   319          3          27
# 976056  653077   287180    6       4         33   319          3          27
# 976057  653079   287180    6       4         33   319          3          27
#
# ...

# %%
import pandas as pd
train = pd.read_csv("data/train/train_data_file.csv")
train
# Out:
# /var/folders/4g/1h_0gphd53sg51js_h0qbbfh0000gn/T/ipykernel_17913/3746736232.py:2: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv("data/train/train_data_file.csv")
#          log_id  label  user_id  age  gender  residence  city  city_rank  \
# 0        373250      0   100005    3       2         16   147          2
# 1        373253      1   100005    3       2         16   147          2
# 2        373252      1   100005    3       2         16   147          2
# 3        373251      0   100005    3       2         16   147          2
# 4        373255      0   100005    3       2         16   147          2
# ...         ...    ...      ...  ...     ...        ...   ...        ...
# 7675512  650508      0   287180    6       4         33   319          3
# 7675513  650492      0   287180    6       4         33   319          3
# 7675514  650509      0   287180    6       4         33   319          3
# ...
